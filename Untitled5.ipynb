# %% [markdown]
# <a href="https://colab.research.google.com/github/noseyukimasa/01/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 自分の顔を動画撮影して肌色の変化を Pyhotn で分析する

# %%
# 顔肌を撮影した動画を用意する:
# 下記コードではファイル名 face.mov を読み込んでいる
# 動画の画素サイズ：2686 × 1761

import cv2
import numpy as np
import matplotlib.pyplot as plt

frames=0; r =[]; g=[]; b=[]
vidcap = cv2.VideoCapture('face.mov')
success, img = vidcap.read()
while success:
    # 顔肌を撮影した動画の大きさに応じて、
    # スライスで抽出するサイズは変更する
    # OpenCVなので色順はBGR
    b.append(np.average(img[1300:1350,1300:1350,0])) # 動画の画像中央部：青色
    g.append(np.average(img[1300:1350,1300:1350,1])) # 動画の画像中央部：緑色
    r.append(np.average(img[1300:1350,1300:1350,2])) # 動画の画像中央部：赤色
    frames += 1; success, img = vidcap.read()

plt.style.use({'figure.figsize': (40, 10)})
plt.rcParams["font.size"] = 72

frames=len(b); x=np.arange(0,1/30*frames,1/30)
plt.ylim([140,220])
plt.xlim([1,7])
plt.grid(color='gray')
plt.plot(x, b, color='blue', lw=6)
plt.plot(x, g, color='green', lw=6)
plt.plot(x, r, color='red', lw=6)

# %% [markdown]
# 鋭いノイズや緩やかな輝度変化を取り除く

# %%
plt.style.use({'figure.figsize': (40, 10)})
plt.rcParams["font.size"] = 72

x = np.arange(0, 1/30*frames, 1/30)
# データを滑らかにする
avedata = np.convolve(g, np.ones(10)/10, mode='same')
# 多項式近似をする
fit = np.poly1d( np.polyfit(x, g, 12))
data = (avedata-fit(x))

plt.ylim([-1,1]); plt.xlim([1,7])
plt.grid(color='gray')
plt.plot(x, data, color='black', lw=6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-20-4291518091.py in <cell line: 0>()
#       4 x = np.arange(0, 1/30*frames, 1/30)
#       5 # データを滑らかにする
# ----> 6 avedata = np.convolve(g, np.ones(10)/10, mode='same')
#       7 # 多項式近似をする
#       8 fit = np.poly1d( np.polyfit(x, g, 12))
#
# /usr/local/lib/python3.11/dist-packages/numpy/_core/numeric.py in convolve(a, v, mode)
#     875         raise ValueError('a cannot be empty')
#     876     if len(v) == 0:
# --> 877         raise ValueError('v cannot be empty')
#     878     return multiarray.correlate(a, v[::-1], mode)
#     879
#
# ValueError: v cannot be empty

# %% [markdown]
# # 新しいセクション

# %%
vidcap=cv2.VideoCapture('face.mov')
frames=0;r=[];g=[];b=[]; success,img=vidcap.read()
while success:
    b.append(np.average(img[1300:1350,1300:1350,0]))
    g.append(np.average(img[1300:1350,1300:1350,1]))
    r.append(np.average(img[1300:1350,1300:1350,2]))
    frames += 1; success, img = vidcap.read()
frames=len(b); x=np.arange(0,1/30*frames,1/30)
plt.plot(x, b); plt.plot(x, g); plt.plot(x, r)
avedata=np.convolve(g, np.ones(10)/10, mode='same')
fit=np.poly1d( np.polyfit(x, g, 12))
plt.plot(x, avedata-fit(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-21-175522628.py in <cell line: 0>()
#       8 frames=len(b); x=np.arange(0,1/30*frames,1/30)
#       9 plt.plot(x, b); plt.plot(x, g); plt.plot(x, r)
# ---> 10 avedata=np.convolve(g, np.ones(10)/10, mode='same')
#      11 fit=np.poly1d( np.polyfit(x, g, 12))
#      12 plt.plot(x, avedata-fit(x))
#
# /usr/local/lib/python3.11/dist-packages/numpy/_core/numeric.py in convolve(a, v, mode)
#     875         raise ValueError('a cannot be empty')
#     876     if len(v) == 0:
# --> 877         raise ValueError('v cannot be empty')
#     878     return multiarray.correlate(a, v[::-1], mode)
#     879
#
# ValueError: v cannot be empty

# %% [markdown]
# pyVHR を使った一般動画からの脈拍推定

# %%
from pyVHR.analysis.pipeline import Pipeline
import matplotlib.pyplot as plt

pipe = Pipeline()
time, BPM, uncertainty = pipe.run_on_video(
    '/Users/jun/Downloads/miyasako_ryo.mov', # ここは適当な動画ファイルを使いましょう
    roi_approach = "patches",
    roi_method = "faceparsing")

plt.figure()
plt.plot(time, BPM)
plt.fill_between(time, BPM-uncertainty,
                 BPM+uncertainty, alpha=0.2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-22-684707758.py in <cell line: 0>()
# ----> 1 from pyVHR.analysis.pipeline import Pipeline
#       2 import matplotlib.pyplot as plt
#       3
#       4 pipe = Pipeline()
#       5 time, BPM, uncertainty = pipe.run_on_video(
#
# ModuleNotFoundError: No module named 'pyVHR'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# データ保存・再読み込み

# %%
import pickle

with open('time.bin', 'wb') as f:
    pickle.dump(time, f)
with open('BPM.bin', 'wb') as f:
    pickle.dump(BPM, f)
with open('uncertainty.bin', 'wb') as f:
    pickle.dump(uncertainty, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-23-3066392760.py in <cell line: 0>()
#       2
#       3 with open('time.bin', 'wb') as f:
# ----> 4     pickle.dump(time, f)
#       5 with open('BPM.bin', 'wb') as f:
#       6     pickle.dump(BPM, f)
#
# NameError: name 'time' is not defined

# %%
import pickle

with open('time.bin', 'rb') as f:
    time2 = pickle.load(f)
with open('BPM.bin', 'rb') as f:
    BPM2 = pickle.load(f)
with open('uncertainty.bin', 'rb') as f:
    uncertainty2 = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# /tmp/ipython-input-24-3479622154.py in <cell line: 0>()
#       2
#       3 with open('time.bin', 'rb') as f:
# ----> 4     time2 = pickle.load(f)
#       5 with open('BPM.bin', 'rb') as f:
#       6     BPM2 = pickle.load(f)
#
# EOFError: Ran out of input

# %% [markdown]
# グラフ描画する

# %%
#plt.figure()
plt.style.use({'figure.figsize': (30, 20)})
plt.rcParams["font.size"] = 80
plt.ylim([20,200])
plt.xlim([0,2000])
plt.grid(color='gray')

plt.plot(time, BPM)
plt.fill_between(time2, BPM2-uncertainty2, BPM2+uncertainty2, alpha=0.2)
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-25-2704303490.py in <cell line: 0>()
#       6 plt.grid(color='gray')
#       7
# ----> 8 plt.plot(time, BPM)
#       9 plt.fill_between(time2, BPM2-uncertainty2, BPM2+uncertainty2, alpha=0.2)
#      10 #plt.show()
#
# NameError: name 'time' is not defined

# %%
from pyVHR.analysis.pipeline import Pipeline
import matplotlib.pyplot as plt

pipe = Pipeline()
time,BPM,uncertainty=pipe.run_on_video('tmp.mov',
 roi_approach="patches",roi_method="faceparsing")
plt.plot(time, BPM)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-26-3448440913.py in <cell line: 0>()
# ----> 1 from pyVHR.analysis.pipeline import Pipeline
#       2 import matplotlib.pyplot as plt
#       3
#       4 pipe = Pipeline()
#       5 time,BPM,uncertainty=pipe.run_on_video('tmp.mov',
#
# ModuleNotFoundError: No module named 'pyVHR'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # 新しいセクション
